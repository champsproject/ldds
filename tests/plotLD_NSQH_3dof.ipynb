# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Non-separable-Quadratic-Hamiltonian:-3-DoF-linear-system" data-toc-modified-id="Non-separable-Quadratic-Hamiltonian:-3-DoF-linear-system-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Non-separable Quadratic Hamiltonian: 3 DoF linear system</a></span><ul class="toc-item"><li><span><a href="#Coordinate:-$(x,-p_x)$" data-toc-modified-id="Coordinate:-$(x,-p_x)$-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Coordinate: $(x, p_x)$</a></span><ul class="toc-item"><li><span><a href="#This-section-plots-the-contour-and-1D-slice-as-a-single-figure-for-compactness" data-toc-modified-id="This-section-plots-the-contour-and-1D-slice-as-a-single-figure-for-compactness-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>This section plots the contour and 1D slice as a single figure for compactness</a></span></li></ul></li><li><span><a href="#Coordinate:-$(y,-p_z)$" data-toc-modified-id="Coordinate:-$(y,-p_z)$-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Coordinate: $(y, p_z)$</a></span></li><li><span><a href="#Coordinate:-$(p_y,-p_z)$" data-toc-modified-id="Coordinate:-$(p_y,-p_z)$-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Coordinate: $(p_y, p_z)$</a></span></li><li><span><a href="#Coordinate:-$(y,-p_y)$" data-toc-modified-id="Coordinate:-$(y,-p_y)$-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Coordinate: $(y, p_y)$</a></span></li><li><span><a href="#Coordinate:-$(z,-p_z)$" data-toc-modified-id="Coordinate:-$(z,-p_z)$-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Coordinate: $(z, p_z)$</a></span></li><li><span><a href="#Coordinate:-$(y,z)$" data-toc-modified-id="Coordinate:-$(y,z)$-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Coordinate: $(y,z)$</a></span></li><li><span><a href="#Coordinate:-$(x,p_z)$" data-toc-modified-id="Coordinate:-$(x,p_z)$-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Coordinate: $(x,p_z)$</a></span></li><li><span><a href="#Coordinate:-$(z,-p_y)$" data-toc-modified-id="Coordinate:-$(z,-p_y)$-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Coordinate: $(z, p_y)$</a></span></li><li><span><a href="#Coordinate:-$(x,z)$" data-toc-modified-id="Coordinate:-$(x,z)$-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Coordinate: $(x,z)$</a></span></li></ul></li></ul></div>

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon Dec 17 06:04:15 2018

@author: Shibabrat Naik
"""

import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
# from pylab import rcParams

mpl.rcParams['mathtext.fontset'] = 'cm' # change fontset for axes labels
mpl.rcParams['mathtext.rm'] = 'serif'
mpl.rcParams['font.family'] = 'serif'

# mpl.rcParams['font.family'] = 'sans-serif'
# mpl.rcParams['font.sans-serif'] = 'Helvetica'
# mpl.rcParams['text.usetex'] = 'True'

# mpl.rcParams['figure.figsize'] = 5, 5

label_size = 25 #10, 20
mpl.rcParams['xtick.labelsize'] = label_size
mpl.rcParams['ytick.labelsize'] = label_size
mpl.rcParams['axes.labelsize'] = 25 #, 15


mpl.rcParams['axes.spines.left'] = True   ## display axis spines
mpl.rcParams['axes.spines.bottom'] = True
mpl.rcParams['axes.spines.top'] = True
mpl.rcParams['axes.spines.right'] = True
mpl.rcParams['xtick.top'] = True
mpl.rcParams['ytick.right'] = True
# mpl.rcParams['xtick.direction'] = 'in'
# mpl.rcParams['ytick.direction'] = 'in'
mpl.rcParams['xtick.direction'] = 'out'
mpl.rcParams['ytick.direction'] = 'out'
mpl.rcParams['xtick.major.size'] = 6
mpl.rcParams['ytick.major.size'] = 6
mpl.rcParams['xtick.major.width'] = 1.5
mpl.rcParams['ytick.major.width'] = 1.5


# from matplotlib import rc
# rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
# ## for Palatino and other serif fonts use:
# #rc('font',**{'family':'serif','serif':['Palatino']})
# rc('text', usetex=True)


LAMBDA = 1.0
OMEGA2 = 1.0
OMEGA3 = 1.0

# %% [markdown]
# ## Non-separable Quadratic Hamiltonian: 3 DoF linear system
#
# Coordinate: $(x, p_x)$

# %%
# %matplotlib

tick_ls = 25 #10, 20
axes_ls = 35 #15, 35
mpl.rcParams['xtick.labelsize'] = tick_ls
mpl.rcParams['ytick.labelsize'] = tick_ls
mpl.rcParams['axes.labelsize'] = axes_ls

colormap_options = ['RdGy', 'viridis', 'inferno', 'bone']
lw_slice = 2  #linewidth for 1D slice
ls_slice = '-' #linestyle for 1D slice

total_energy = 0.2
# check the domain in the C++ code
xRes = 400
yRes = 400
# xGrid = np.linspace(-0.05, 0.05, xRes + 1)
# yGrid = np.linspace(-0.05, 0.05, yRes + 1)

xGrid = np.linspace(-1, 1, xRes + 1)
yGrid = np.linspace(-1, 1, yRes + 1)


xMesh, yMesh = np.meshgrid(xGrid, yGrid)

# MMesh = np.genfromtxt("../src/test_M" + str(xRes) + "x" + str(yRes) + 
#                       "_finalT20_q1-p1_p1-pos.txt",delimiter="\t")

MMesh = np.genfromtxt("../data/linear-3dof/symp-transform-xpx/lag_des_3dof" 
                      + str(xRes) + "x" + str(yRes) 
                      + "_finalT10_E%.6f"%(total_energy) + ".txt",delimiter="\t")

# Query few sample values
y_val1_idx = 0.5*yRes
y_val1 = yMesh[int(y_val1_idx),0]
print(y_val1)

y_val2_idx = 0.75*yRes
y_val2 = yMesh[int(y_val2_idx),0]
print(y_val2)

y_val3_idx = 0.9*yRes 
y_val3 = yMesh[int(y_val3_idx),0]
print(y_val3)

plt.close('all')
fig_cf = plt.figure(figsize=(8,8))
ax_cf = fig_cf.gca()
cf = ax_cf.contourf(xMesh, yMesh, MMesh[:,:], 100, cmap = colormap_options[1])

ax_cf.plot(xMesh[int(y_val1_idx),:], yMesh[int(y_val1_idx),:],'k', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$y = %.2f$'%y_val1)

ax_cf.plot(xMesh[int(y_val2_idx),:], yMesh[int(y_val2_idx),:],'m', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$y = %.2f$'%y_val2)

ax_cf.plot(xMesh[int(y_val3_idx),:], yMesh[int(y_val3_idx),:],'b', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$y = %.2f$'%y_val3)

ax_cf.set_xlabel(r'$q_1$')
ax_cf.set_ylabel(r'$p_1$')
ax_cf.set_title(r'$q_2 = q_3 = p_3 = 0$', fontsize = 25)
#fig_cf.colorbar(cf)
plt.tight_layout()
# plt.savefig('lag_desc_3dof_linear_saddle_coords.pdf')
plt.show()


fig_graphM = plt.figure(figsize=(8,8))
ax_graphM = fig_graphM.gca()
ax_graphM.plot(xMesh[int(y_val1_idx),:], MMesh[int(y_val1_idx),:], 'k', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$y = %.2f$'%y_val1)

ax_graphM.plot(xMesh[int(y_val2_idx),:], MMesh[int(y_val2_idx),:], 'm', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$y = %.2f$'%y_val2)

ax_graphM.plot(xMesh[int(y_val3_idx),:], MMesh[int(y_val3_idx),:],'b', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$y = %.2f$'%y_val3)

ax_graphM.set_xlabel(r'$x$')
ax_graphM.set_ylabel(r'$M_{0.5}$') 
# ax_graphM.set_title(r'$y = %f$'%y_val1, fontsize = 20)
ax_graphM.legend(fontsize = 20)

#fig_cf.colorbar(cf)
plt.tight_layout()
# plt.savefig('graphM_3dof_linear_saddle_coords.pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-aa230e61b85b> in <module>()
#      30 MMesh = np.genfromtxt("../data/linear-3dof/symp-transform-xpx/lag_des_3dof"
#      31                       + str(xRes) + "x" + str(yRes)
# ---> 32                       + "_finalT10_E%.6f"%(total_energy) + ".txt",delimiter="\t")
#      33
#      34 # Query few sample values
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    1687             fname = str(fname)
#    1688         if isinstance(fname, basestring):
# -> 1689             fhd = iter(np.lib._datasource.open(fname, 'rt', encoding=encoding))
#    1690             own_fhd = True
#    1691         else:
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     258
#     259     ds = DataSource(destpath)
# --> 260     return ds.open(path, mode, encoding=encoding, newline=newline)
#     261
#     262
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     614                                       encoding=encoding, newline=newline)
#     615         else:
# --> 616             raise IOError("%s not found." % path)
#     617
#     618
#
# OSError: ../data/linear-3dof/symp-transform-xpx/lag_des_3dof400x400_finalT10_E0.200000.txt not found.

# %% [markdown]
# ### Coordinate: $(x, p_x)$
#
# #### This section plots the contour and 1D slice as a single figure for compactness

# %%
tick_ls = 25 #10, 20
axes_ls = 35 #15, 35
mpl.rcParams['xtick.labelsize'] = tick_ls
mpl.rcParams['ytick.labelsize'] = tick_ls
mpl.rcParams['axes.labelsize'] = axes_ls

colormap_options = ['RdGy', 'viridis', 'inferno', 'bone']
lw_slice = 2  #linewidth for 1D slice
ls_slice = '-' #linestyle for 1D slice

total_energy = 0.2
xRes = 400
yRes = 400
xVec = np.linspace(-1, 1.0, xRes+1)
yVec = np.linspace(-1, 1.0, yRes+1)
xMesh, yMesh = np.meshgrid(xVec, yVec)

OMEGA2 = 1.0
OMEGA3 = 1.0

MMesh = np.genfromtxt("../data/linear-3dof/symp-transform-xpx/lag_des_3dof" 
                      + str(xRes) + "x" + str(yRes) 
                      + "_finalT10_E%.6f"%(total_energy) + ".txt",delimiter="\t")

# MMesh = np.genfromtxt("../src/test_M" + str(xRes) + "x" + str(yRes) + 
#                       "_finalT10_E0.100000.txt",delimiter="\t")t

# min_MMesh, max_MMesh = find_max_min_nan_mat(MMesh)

# normi = mpl.colors.Normalize(vmin = 18, vmax = 558)

# Query few sample values
y_val1_idx = 0.25*yRes
y_val1 = yMesh[int(y_val1_idx),0]
# print(y_val1)

y_val2_idx = 0.5*yRes
y_val2 = yMesh[int(y_val2_idx),0]
# print(y_val2)

y_val3_idx = 0.65*yRes 
y_val3 = yMesh[int(y_val3_idx),0]
# print(y_val3)


# fig_cf = plt.figure(figsize = (10,10))
fig_cf, axarr = plt.subplots(2, 1, sharex = True, figsize=(10,10))
ax_cf = axarr[1]
ax_graphM = axarr[0]
# ax_cf = fig_cf.gca()
# ax_cf = fig_cf.add_subplot(2,1,1, aspect = 'equal')
# ax_graphM = fig_cf.add_subplot(2,1,2)
cf = ax_cf.contourf(xMesh, yMesh, MMesh[:,:], 100, cmap = colormap_options[1])

ax_cf.plot(xMesh[int(y_val1_idx),:], yMesh[int(y_val1_idx),:],'k', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$y = %.2f$'%y_val1)

ax_cf.plot(xMesh[int(y_val2_idx),:], yMesh[int(y_val2_idx),:],'m', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$y = %.2f$'%y_val2)

ax_cf.plot(xMesh[int(y_val3_idx),:], yMesh[int(y_val3_idx),:],'b', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$y = %.2f$'%y_val3)

"""
Plotting the analytical NHIM as contour and not masking the values 
which are on the imposed direction of slice 
"""
ax_cf.plot(np.sqrt(total_energy/(0.5*OMEGA2+OMEGA3)), 0, 'Xr', Markersize = 15)

res = 100
xMesh_mani, yMesh_mani = np.meshgrid(np.linspace(-1,1,res), np.linspace(-1,1,res))
umani = OMEGA2*(xMesh_mani + yMesh_mani)**2 + \
            OMEGA3*( (xMesh_mani + yMesh_mani)**2 + xMesh_mani**2 ) - 2*total_energy
smani = OMEGA2*(xMesh_mani - yMesh_mani)**2 + \
            OMEGA3*( (xMesh_mani - yMesh_mani)**2 + (xMesh_mani - 2.0*yMesh_mani)**2 ) - 2*total_energy

mask_umani = np.zeros_like(umani, dtype = np.bool)
mask_smani = np.zeros_like(smani, dtype = np.bool)
# # mask[0:res,:] = True
# # mask[:,0:30] = True
for i, x in enumerate(xMesh_mani[0,:]):
    for j, y in enumerate(yMesh_mani[:,0]):
        if LAMBDA*y + OMEGA2*(x + y) + OMEGA3*(y + 2*x) < 0:
            mask_umani[j,i] = True
        if LAMBDA*(-y) + OMEGA2*(x - y) + OMEGA3*(2*x - 3*y) < 0:
            mask_smani[j,i] = True

# Don't mask NHIM that is the sice with the correct direction.            
umani = np.ma.array(umani, mask = mask_umani)
smani = np.ma.array(smani, mask = mask_smani)
ax_cf.contour(xMesh_mani, yMesh_mani, umani, [0],
                colors = 'red', alpha = 1.0, linestyles = 'dashdot',
                 linewidths = 3)
ax_cf.contour(xMesh_mani, yMesh_mani, smani, [0],
                colors = 'white', alpha = 1.0, linestyles = 'dashed',
                 linewidths = 3)



# ax_cf.set_xlabel(r'$p_y$',  fontsize = fs + 10)
# ax_cf.set_ylabel(r'$p_z$',  fontsize = fs + 10)

ax_cf.set_xlabel(r'$x$',  fontsize = axes_ls + 10)
ax_cf.set_ylabel(r'$p_x$',  fontsize = axes_ls + 10)

# ax_cf.set_xlim([-0.2, 0.2])
# ax_cf.set_ylim([-0.2, 0.2])
ax_cf.set_xticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_aspect('equal')

# ax_cf.set_title(r'$q_1 = q_3 = p_3 = 0, p_1 < 0$', fontsize = 25)
# fig_cf.colorbar(cf)
# cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05,
#                        drawedges = False)

plt.tight_layout()
# plt.savefig('lag_desc_3dof_linear_center_coords.pdf')
plt.show()

# fig_graphM = plt.figure(figsize=(8,8))
# ax_graphM = fig_graphM.gca()
ax_graphM.plot(xMesh[int(y_val1_idx),:], MMesh[int(y_val1_idx),:], 'k', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$p_x = %.2f$'%y_val1)

ax_graphM.plot(xMesh[int(y_val2_idx),:], MMesh[int(y_val2_idx),:], 'm', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$p_x = %.2f$'%y_val2)

ax_graphM.plot(xMesh[int(y_val3_idx),:], MMesh[int(y_val3_idx),:], 'b', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$p_x = %.2f$'%y_val3)

# ax_graphM.plot(np.sqrt(total_energy/(0.5*OMEGA2 + OMEGA3)), ax_graphM.get_ybound()[0], 'xr', Markersize = 10)

# from sympy import symbols, plot_implicit, Eq
# x, y = symbols('x y')

# # fig, ax = plt.subplots(1,1)
# xx,yy = np.linspace(-1,1), np.linspace(-1,1)
# x,y = np.meshgrid(xx,yy)
# ax_cf.contour(x, y, (x**2 + 0.5*y**2 - x*y - E), [0]);
# ax_cf.contour(x, y, (2*x - y), [0]);
# ax_cf.set_aspect('equal','datalim')
# # ax.set_xlabel(r'$x$')
# # ax.set_ylabel(r'$y$', rotation = 0)

# ax_graphM.set_xlabel(r'$x$',  fontsize = fs + 10)
ax_graphM.legend(fontsize = axes_ls - 15)
ax_graphM.set_ylabel(r'$M_{0.5}$',  fontsize = axes_ls + 5)
ax_graphM.set_xlim([-1, 1])
ax_graphM.set_aspect(1.0/ax_graphM.get_data_ratio())

# ax_graphM.set_ylim([min_MMesh, 75])
# # ax_graphM.set_title(r'$y = %f$'%y_val1, fontsize = 20)
# ax_graphM.legend(fontsize = 15)
# #fig_cf.colorbar(cf)
# ax_graphM.set_aspect('equal')


plt.tight_layout()

plt.savefig('../data/linear-3dof/symp-transform-xpx/linear_symp_trans_3dof_M' 
            + str(xRes) + 'x' + str(yRes) + '_E%.0e'%(total_energy) + '_xpx.png', 
            dpi = 600, bbox_inches = 'tight')

plt.show()

# %% [markdown]
# ### Coordinate: $(y, p_z)$
#
# \begin{equation}
# U_{yp_z}^+ = \left\{(y, p_z) \; | \; x = 0, \; z = 0, \; p_x = 0, \; p_y(x,y,z,p_x,p_z;e) : \dot{x}(\cdot) > 0 \right\}, \label{eqn:sos_symp_3dof_ypz}
# \end{equation}

# %%
# %matplotlib

colormap_options = ['RdGy', 'viridis', 'inferno', 'bone']
lw_slice = 2  #linewidth for 1D slice
ls_slice = '-' #linestyle for 1D slice

tick_ls = 25 #10, 20
axes_ls = 35 #15, 35
mpl.rcParams['xtick.labelsize'] = tick_ls
mpl.rcParams['ytick.labelsize'] = tick_ls
mpl.rcParams['axes.labelsize'] = axes_ls


total_energy = 0.2
xRes = 1000
yRes = 1000
xVec = np.linspace(-1, 1.0, xRes+1)
yVec = np.linspace(-1, 1.0, yRes+1)
xMesh, yMesh = np.meshgrid(xVec, yVec)


MMesh = np.genfromtxt("../data/linear-3dof/symp-transform-ypz-xdot_pos/lag_des_3dof" 
                      + str(xRes) + "x" + str(yRes) 
                      + "_finalT10_E%.6f"%(total_energy) + ".txt",delimiter="\t")

# MMesh = np.genfromtxt("../data/linear-3dof/symp-transform-ypz_py_pos/lag_des_3dof" 
#                       + str(xRes) + "x" + str(yRes) 
#                       + "_finalT10_E%.6f"%(total_energy) + ".txt",delimiter="\t")

# MMesh = np.genfromtxt("../src/test_M" + str(xRes) + "x" + str(yRes) + 
#                       "_finalT10_E0.100000.txt",delimiter="\t")t

# min_MMesh, max_MMesh = find_max_min_nan_mat(MMesh)

# normi = mpl.colors.Normalize(vmin = 18, vmax = 558)

# Query few sample values
y_val1_idx = 0.35*yRes
y_val1 = yMesh[int(y_val1_idx),0]
# print(y_val1)

y_val2_idx = 0.45*yRes
y_val2 = yMesh[int(y_val2_idx),0]
# print(y_val2)

y_val3_idx = 0.55*yRes 
y_val3 = yMesh[int(y_val3_idx),0]
# print(y_val3)


plt.close('all')
fig_cf = plt.figure()
ax_cf = fig_cf.gca()

cf = ax_cf.contourf(xMesh, yMesh, MMesh, 
                    400, cmap = 'viridis')
# cf = ax_cf.contourf(xMesh, yMesh, np.arctan(MMesh[:,:]), 
#                     400, cmap = 'viridis')


ax_cf.set_xlabel(r'$y$')
ax_cf.set_ylabel(r'$p_z$') 

# cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05,
#                        drawedges = True)
# cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05, 
#                        ticks = [min_MMesh, max_MMesh],
#                        drawedges = True)
# cbar.ax.set_yticklabels(['Min', 'Max'])
ax_cf.set_aspect('equal')
ax_cf.set_xticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
plt.tight_layout()
# plt.savefig('lag_desc_linear_2dof_finalT10_E0-4_p1p2_q1zero_tau10.png', dpi = 300,
#             bbox_inches = 'tight')
plt.show()


# fig_cf = plt.figure(figsize = (10,10))
fig_cf, axarr = plt.subplots(2, 1, sharex = True, figsize=(10,10))
ax_cf = axarr[1]
ax_graphM = axarr[0]
# ax_cf = fig_cf.gca()
# ax_cf = fig_cf.add_subplot(2,1,1, aspect = 'equal')
# ax_graphM = fig_cf.add_subplot(2,1,2)
cf = ax_cf.contourf(xMesh, yMesh, MMesh[:,:], 200, 
                    cmap = 'viridis')

ax_cf.plot(xMesh[int(y_val1_idx),:], yMesh[int(y_val1_idx),:],'k', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$y = %.2f$'%y_val1)

ax_cf.plot(xMesh[int(y_val2_idx),:], yMesh[int(y_val2_idx),:],'m', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$y = %.2f$'%y_val2)

ax_cf.plot(xMesh[int(y_val3_idx),:], yMesh[int(y_val3_idx),:],'b', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$y = %.2f$'%y_val3)

"""
# Plotting the analytical NHIM as contour and not masking the values which are on the imposed direction of slice 
"""
xMesh_nhim, yMesh_nhim = np.meshgrid(np.linspace(-1,1,100), np.linspace(-1,1,100))
nhim = (OMEGA2*xMesh_nhim**2 + (OMEGA2 + OMEGA3)*yMesh_nhim**2 - 2*total_energy)

mask = np.zeros_like(nhim, dtype=np.bool)
# mask[0:-1, 0:30] = True
# mask[0:30,0:-1] = True
for i, x in enumerate(xMesh_nhim[0,:]):
    for j, y in enumerate(yMesh_nhim[:,0]):
        if x < 0:
            mask[j,i] = True 

# Don't mask NHIM that is the sice with the correct direction.            
nhim = np.ma.array(nhim, mask = ~mask)

ax_cf.contour(xMesh_nhim, yMesh_nhim, nhim, [0], 
              colors = 'red', alpha = 1.0, linestyles = 'dashdot',
              linewidths = 3)

# Unstable and stable manifolds project as the same as NHIM on this 2D surface
ax_cf.contour(xMesh_nhim, yMesh_nhim, nhim, [0], 
              colors = 'red', alpha = 1.0, linestyles = 'dashed',
              linewidths = 3)

ax_cf.contour(xMesh_nhim, yMesh_nhim, nhim, [0], 
              colors = 'white', alpha = 1.0, linestyles = 'dashed',
              linewidths = 3)


# ax_cf.set_xlabel(r'$p_y$',  fontsize = fs + 10)
# ax_cf.set_ylabel(r'$p_z$',  fontsize = fs + 10)

ax_cf.set_xlabel(r'$y$',  fontsize = axes_ls + 10)
ax_cf.set_ylabel(r'$p_z$',  fontsize = axes_ls + 10)

# ax_cf.set_xlim([-0.2, 0.2])
# ax_cf.set_ylim([-0.2, 0.2])
ax_cf.set_xticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_aspect('equal')

# ax_cf.set_title(r'$q_1 = q_3 = p_3 = 0, p_1 < 0$', fontsize = 25)
# fig_cf.colorbar(cf)
# cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05,
#                        drawedges = False)

plt.tight_layout()
# plt.savefig('lag_desc_3dof_linear_center_coords.pdf')
plt.show()

# fig_graphM = plt.figure(figsize=(8,8))
# ax_graphM = fig_graphM.gca()
ax_graphM.plot(xMesh[int(y_val1_idx),:], MMesh[int(y_val1_idx),:], 'k', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$p_x = %.2f$'%y_val1)

ax_graphM.plot(xMesh[int(y_val2_idx),:], MMesh[int(y_val2_idx),:], 'm', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$p_x = %.2f$'%y_val2)

ax_graphM.plot(xMesh[int(y_val3_idx),:], MMesh[int(y_val3_idx),:], 'b', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$p_x = %.2f$'%y_val3)


# ax_graphM.set_xlabel(r'$x$',  fontsize = fs + 10)
ax_graphM.legend(fontsize = axes_ls - 15)
ax_graphM.set_ylabel(r'$M_{0.5}$',  fontsize = axes_ls + 5)
ax_graphM.set_xlim([-1, 1])
ax_graphM.set_aspect(1.0/ax_graphM.get_data_ratio())

# ax_graphM.set_ylim([min_MMesh, 75])
# # ax_graphM.set_title(r'$y = %f$'%y_val1, fontsize = 20)
# ax_graphM.legend(fontsize = 15)
# #fig_cf.colorbar(cf)
# ax_graphM.set_aspect('equal')


plt.tight_layout()

# plt.savefig('../data/linear-3dof/symp-transform-ypz-xdot_pos/linear_symp_trans_3dof_M' 
#             + str(xRes) + 'x' + str(yRes) + '_E%.0e'%(total_energy) + '_ypz.png', 
#             dpi = 600, bbox_inches = 'tight')

plt.show()

# %% [markdown]
# ### Coordinate: $(p_y, p_z)$

# %%
# Solving for px, given py, pz, and total energy, and x = y = z = 0
def get_px_linear_symp_3dof(p2, p3, total_energy):
    
    
    px = []

    a = ( 0.5*OMEGA2 + 0.5*OMEGA3 );
    b = ( LAMBDA*(p2 + p3) + OMEGA2*(p2 + p3) + OMEGA3*(p2 + p3) );
    c = ( 0.5*LAMBDA*(p2**2 + p3**2) + LAMBDA*p2*p3 + \
             OMEGA2*(p2**2 + 0.5*p3**2 + p2*p3) + \
             OMEGA3*(0.5*p2**2 + p3**2 + p2*p3) - total_energy );

    # Two solutions of the quadratic
    px1 = (-b + np.sqrt( b**2 - 4.0*a*c ))/(2.0*a);
    px2 = (-b - np.sqrt( b**2 - 4.0*a*c ))/(2.0*a);

    # check the sign of q1_dot 
    q1_dot1 = LAMBDA*(p2 + p3) + OMEGA2*(px1 + p2 + p3) + OMEGA3*(px1 + p2 + p3);
    
    q1_dot2 = LAMBDA*(p2 + p3) + OMEGA2*(px2 + p2 + p3) + OMEGA3*(px2 + p2 + p3); 

    for i in range(len(q1_dot1)):
        if (q1_dot1[i] > 0):
            px.append(px1)
        elif (q1_dot2[i] > 0):
            px.append(px2)
        else:
            px.append(NAN)
    
    return px

# %%
# %matplotlib

only_colormap = 'False'
colormap_options = ['RdGy', 'viridis', 'inferno', 'bone']
lw_slice = 2  #linewidth for 1D slice
ls_slice = '-' #linestyle for 1D slice


tick_ls = 20 #10, 20
axes_ls = 35 #15, 35
mpl.rcParams['xtick.labelsize'] = tick_ls
mpl.rcParams['ytick.labelsize'] = tick_ls
mpl.rcParams['axes.labelsize'] = axes_ls


total_energy = 0.2
xRes = 1000
yRes = 1000
xVec = np.linspace(-1, 1.0, xRes+1)
yVec = np.linspace(-1, 1.0, yRes+1)
xMesh, yMesh = np.meshgrid(xVec, yVec)

OMEGA2 = 1.0
OMEGA3 = 1.0


MMesh = np.genfromtxt("../data/linear-3dof/symp-transform-pypz-xdot_pos/lag_des_3dof" 
                      + str(xRes) + "x" + str(yRes) 
                      + "_finalT10_E%.6f"%(total_energy) + ".txt",delimiter="\t")

# MMesh = np.genfromtxt("../src/lag_des_3dof" + str(xRes) + "x" + str(yRes) 
#                       + "_finalT10_E%.6f"%(total_energy) + ".txt", delimiter="\t")

# MMesh = np.arctan(MMesh)

# min_MMesh, max_MMesh = find_max_min_nan_mat(MMesh)

# normi = mpl.colors.Normalize(vmin = 18, vmax = 558)

# Query few sample values
y_val1_idx = 0.275*yRes # E = 0.2
# y_val1_idx = 0.28*yRes # E = 0.2
# y_val1_idx = 0.19*yRes # E = 0.4
y_val1 = yMesh[int(y_val1_idx),0]
# print(y_val1)

y_val2_idx = 0.5*yRes
y_val2 = yMesh[int(y_val2_idx),0]
# print(y_val2)

y_val3_idx = 0.725*yRes # E = 0.1
# y_val3_idx = 0.72*yRes # E = 0.2
# y_val3_idx = 0.82*yRes # E = 0.4
y_val3 = yMesh[int(y_val3_idx),0]
# print(y_val3)


if only_colormap == 'True':
    plt.close('all')
    fig_cf = plt.figure()
    ax_cf = fig_cf.gca()

    cf = ax_cf.contourf(xMesh, yMesh, MMesh, 
                        400, cmap = 'viridis')
    # cf = ax_cf.contourf(xMesh, yMesh, np.arctan(MMesh[:,:]), 
    #                     400, cmap = 'viridis')


    ax_cf.set_xlabel(r'$p_y$')
    ax_cf.set_ylabel(r'$p_z$') 

    # cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05,
    #                        drawedges = True)
    # cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05, 
    #                        ticks = [min_MMesh, max_MMesh],
    #                        drawedges = True)
    # cbar.ax.set_yticklabels(['Min', 'Max'])
    ax_cf.set_aspect('equal')
    ax_cf.set_xticks([-1.0, -0.5, 0.0, 0.5, 1.0])
    ax_cf.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
    plt.tight_layout()
    # plt.savefig('lag_desc_linear_2dof_finalT10_E0-4_p1p2_q1zero_tau10.png', dpi = 300,
    #             bbox_inches = 'tight')
    plt.show()


# fig_cf = plt.figure(figsize = (10,10))
fig_cf, axarr = plt.subplots(2, 1, sharex = True, figsize=(10,10))
ax_cf = axarr[1]
ax_graphM = axarr[0]
# ax_cf = fig_cf.gca()
# ax_cf = fig_cf.add_subplot(2,1,1, aspect = 'equal')
# ax_graphM = fig_cf.add_subplot(2,1,2)
cf = ax_cf.contourf(xMesh, yMesh, MMesh[:,:], 200, 
                    cmap = colormap_options[1])

ax_cf.plot(xMesh[int(y_val1_idx),:], yMesh[int(y_val1_idx),:],'k', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$p_z = %.2f$'%y_val1)

ax_cf.plot(xMesh[int(y_val2_idx),:], yMesh[int(y_val2_idx),:],'m', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$p_z = %.2f$'%y_val2)

ax_cf.plot(xMesh[int(y_val3_idx),:], yMesh[int(y_val3_idx),:],'b', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$p_z = %.2f$'%y_val3)



"""
# Plotting the analytical NHIM as contour and not masking the values which are on the imposed direction of slice 
"""

ax_cf.plot(np.sqrt(2*total_energy/(OMEGA2+OMEGA3)), -np.sqrt(2*total_energy/(OMEGA2+OMEGA3)), 
           'Xr', Markersize = 15)
ax_cf.plot(-np.sqrt(2*total_energy/(OMEGA2+OMEGA3)), np.sqrt(2*total_energy/(OMEGA2+OMEGA3)), 
           'Xr', Markersize = 15)

res = 1000
xMesh_nhim, yMesh_nhim = np.meshgrid(np.linspace(-1,1,res), np.linspace(-1,1,res))
umani = (OMEGA2*xMesh_nhim**2 + OMEGA3*yMesh_nhim**2 - 2*total_energy)

mask = np.zeros_like(umani, dtype=np.bool)
# mask[0:-1, 0:30] = True
# mask[0:30,0:-1] = True
for i, x in enumerate(xMesh_nhim[0,:]):
    for j, y in enumerate(yMesh_nhim[:,0]):
        if (x + y) > 0:
            mask[j,i] = True 

# Don't mask NHIM that is the sice with the correct direction.            
umani = np.ma.array(umani, mask = ~mask)

# cs = ax_cf.contour(xMesh_nhim, yMesh_nhim, umani, [0], 
#                   colors = 'red', alpha = 1.0, linestyles = 'dashdot',
#                   linewidths = 3)

# p = cs.collections[0].get_paths()[0]
# v = p.vertices
# x = v[:,0]
# y = v[:,1]

# ax_cf.plot(x,y,'-r')

# px = get_px_linear_symp_3dof(x,y,total_energy)


ax_cf.set_xlabel(r'$p_y$',  fontsize = axes_ls)
ax_cf.set_ylabel(r'$p_z$',  fontsize = axes_ls)

ax_cf.set_xticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_aspect('equal')

# ax_cf.set_title(r'$q_1 = q_3 = p_3 = 0, p_1 < 0$', fontsize = 25)
# fig_cf.colorbar(cf)
# cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05,
#                        drawedges = False)

plt.tight_layout()
# plt.savefig('lag_desc_3dof_linear_center_coords.pdf')
plt.show()

# fig_graphM = plt.figure(figsize=(8,8))
# ax_graphM = fig_graphM.gca()
ax_graphM.plot(xMesh[int(y_val1_idx),:], MMesh[int(y_val1_idx),:], 'k', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$p_z = %.2f$'%y_val1)

ax_graphM.plot(xMesh[int(y_val2_idx),:], MMesh[int(y_val2_idx),:], 'm', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$p_z = %.2f$'%y_val2)

ax_graphM.plot(xMesh[int(y_val3_idx),:], MMesh[int(y_val3_idx),:], 'b', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$p_z = %.2f$'%y_val3)

# ax_graphM.set_xlabel(r'$x$',  fontsize = fs + 10)
ax_graphM.legend(fontsize = axes_ls - 15)
ax_graphM.set_ylabel(r'$M_{0.5}$',  fontsize = axes_ls)
ax_graphM.set_xlim([-1, 1])
ax_graphM.set_aspect(1.0/ax_graphM.get_data_ratio())

# ax_graphM.set_ylim([min_MMesh, 75])
# # ax_graphM.set_title(r'$y = %f$'%y_val1, fontsize = 20)
# ax_graphM.legend(fontsize = 15)
# #fig_cf.colorbar(cf)
# ax_graphM.set_aspect('equal')

plt.tight_layout()

# plt.savefig('../data/linear-3dof/symp-transform-pypz-xdot_pos/linear_symp_trans_3dof_M' 
#             + str(xRes) + 'x' + str(yRes) + '_E%.0e'%(total_energy) + '_pypz.png', 
#             dpi = 600, bbox_inches = 'tight')

# plt.show()
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# ### Coordinate: $(y, p_y)$

# %%
# %matplotlib

colormap_options = ['RdGy', 'viridis', 'inferno', 'bone']
lw_slice = 2  #linewidth for 1D slice
ls_slice = '-' #linestyle for 1D slice

tick_ls = 25 #10, 20
axes_ls = 35 #15, 35
mpl.rcParams['xtick.labelsize'] = tick_ls
mpl.rcParams['ytick.labelsize'] = tick_ls
mpl.rcParams['axes.labelsize'] = axes_ls


total_energy = 0.2
xRes = 500
yRes = 500
xVec = np.linspace(-1.0, 1.0, xRes+1)
yVec = np.linspace(-1.0, 1.0, yRes+1)
xMesh, yMesh = np.meshgrid(xVec, yVec)

data_path = "../data/linear-3dof/symp-transform-ypy-xdot_pos/"

MMesh = np.genfromtxt( data_path + "lag_des_3dof" 
                      + str(xRes) + "x" + str(yRes) 
                      + "_finalT10_E%.6f"%(total_energy) + ".txt",delimiter="\t")

# MMesh = np.genfromtxt("../data/linear-3dof/symp-transform-ypz_py_pos/lag_des_3dof" 
#                       + str(xRes) + "x" + str(yRes) 
#                       + "_finalT10_E%.6f"%(total_energy) + ".txt",delimiter="\t")

# MMesh = np.genfromtxt("../src/test_M" + str(xRes) + "x" + str(yRes) + 
#                       "_finalT10_E0.100000.txt",delimiter="\t")t

# min_MMesh, max_MMesh = find_max_min_nan_mat(MMesh)

# normi = mpl.colors.Normalize(vmin = 18, vmax = 558)

# Query few sample values
val1_idx = 0.1*xRes
val1 = xMesh[0,int(val1_idx)]

val2_idx = 0.190*xRes
val2 = xMesh[0,int(val2_idx)]

val3_idx = 0.5*xRes 
val3 = xMesh[0,int(val3_idx)]
# print(val1)
# print(val2)
# print(val3)


plt.close('all')
# fig_cf = plt.figure(figsize = (10,10))
fig_cf, axarr = plt.subplots(2, 1, sharex = True, figsize=(10,10))
ax_cf = axarr[1]
ax_graphM = axarr[0]
# ax_cf = fig_cf.gca()
# ax_cf = fig_cf.add_subplot(2,1,1, aspect = 'equal')
# ax_graphM = fig_cf.add_subplot(2,1,2)
cf = ax_cf.contourf(xMesh, yMesh, MMesh[:,:], 200, 
                    cmap = 'viridis')

ax_cf.plot(xMesh[:,int(val1_idx)], yMesh[:,int(val1_idx)],'k', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$y = %.2f$'%val1)

ax_cf.plot(xMesh[:,int(val2_idx)], yMesh[:,int(val2_idx)],'m', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$y = %.2f$'%val2)

ax_cf.plot(xMesh[:,int(val3_idx)], yMesh[:,int(val3_idx)],'b', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$y = %.2f$'%val3)


"""
# Plotting the analytical NHIM as contour and not masking the values which are on the imposed direction of slice 
"""

ax_cf.plot(-np.sqrt((2*total_energy)/OMEGA2), 0, 'Xr', Markersize = 15)


xMesh_nhim, yMesh_nhim = np.meshgrid(np.linspace(-1,1,100), np.linspace(-1,1,100))
umani = (OMEGA2*(xMesh_nhim**2 + yMesh_nhim**2) - 2*total_energy)
smani = OMEGA2*( (-xMesh_nhim + 0.5*yMesh_nhim)**2 + yMesh_nhim**2 ) + \
        ( (OMEGA3/0.9)*yMesh_nhim**2 ) - 2*total_energy # check the coefficient of OMEGA3 here 

umask = np.zeros_like(umani, dtype=np.bool)
smask = np.zeros_like(smani, dtype=np.bool)
# mask[0:-1, 0:30] = True
# mask[0:30,0:-1] = True
for i, x in enumerate(xMesh_nhim[0,:]):
    for j, y in enumerate(yMesh_nhim[:,0]):
        if -OMEGA2*x > 0:
            umask[j,i] = True
        if (LAMBDA + 0.5*OMEGA2 + 0.5*OMEGA3)*y - OMEGA2*x > 0:
            smask[j,i] = True

# Don't mask NHIM that is the sice with the correct direction.            
umani = np.ma.array(umani, mask = ~umask)
smani = np.ma.array(smani, mask = ~smask)

# Unstable and stable manifolds project as the same as NHIM on this 2D surface
# ax_cf.contour(xMesh_nhim, yMesh_nhim, umani, [0], 
#               colors = 'red', alpha = 1.0, linestyles = 'dashed',
#               linewidths = 3)

ax_cf.contour(xMesh_nhim, yMesh_nhim, smani, [0], 
              colors = 'white', alpha = 1.0, linestyles = 'dashed',
              linewidths = 3)


# ax_cf.set_xlabel(r'$p_y$',  fontsize = fs + 10)
# ax_cf.set_ylabel(r'$p_z$',  fontsize = fs + 10)

ax_cf.set_xlabel(r'$y$',  fontsize = axes_ls + 10)
ax_cf.set_ylabel(r'$p_y$',  fontsize = axes_ls + 10)

# ax_cf.set_xlim([-0.2, 0.2])
# ax_cf.set_ylim([-0.2, 0.2])
ax_cf.set_xticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_aspect('equal')

# ax_cf.set_title(r'$q_1 = q_3 = p_3 = 0, p_1 < 0$', fontsize = 25)
# fig_cf.colorbar(cf)
# cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05,
#                        drawedges = False)

plt.tight_layout()
# plt.savefig('lag_desc_3dof_linear_center_coords.pdf')
plt.show()

# fig_graphM = plt.figure(figsize=(8,8))
# ax_graphM = fig_graphM.gca()

ax_graphM.plot(yMesh[:,int(val1_idx)], MMesh[:,int(val1_idx)], 'k', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$y = %.2f$'%val1)

ax_graphM.plot(yMesh[:,int(val1_idx)], MMesh[:,int(val2_idx)], 'm', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$y = %.2f$'%val2)

ax_graphM.plot(yMesh[:,int(val1_idx)], MMesh[:,int(val3_idx)],'b', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$y = %.2f$'%val3)


# ax_graphM.set_xlabel(r'$x$',  fontsize = fs + 10)
ax_graphM.legend(fontsize = axes_ls - 15, loc = 2)
ax_graphM.set_ylabel(r'$M_{0.5}$',  fontsize = axes_ls + 5)
ax_graphM.set_xlim([-1, 1])
ax_graphM.set_aspect(1.0/ax_graphM.get_data_ratio())

# ax_graphM.set_ylim([min_MMesh, 75])
# # ax_graphM.set_title(r'$y = %f$'%y_val1, fontsize = 20)
# ax_graphM.legend(fontsize = 15)
# #fig_cf.colorbar(cf)
# ax_graphM.set_aspect('equal')


# plt.tight_layout()

plt.savefig('../data/linear-3dof/symp-transform-ypy-xdot_pos/linear_symp_trans_3dof_M' 
            + str(xRes) + 'x' + str(yRes) + '_E%.0e'%(total_energy) + '_ypy.png', 
            dpi = 600, bbox_inches = 'tight')

plt.show()

# %% [markdown]
# ### Coordinate: $(z, p_z)$

# %%
# %matplotlib

colormap_options = ['RdGy', 'viridis', 'inferno', 'bone']
lw_slice = 2  #linewidth for 1D slice
ls_slice = '-' #linestyle for 1D slice

tick_ls = 25 #10, 20
axes_ls = 35 #15, 35
mpl.rcParams['xtick.labelsize'] = tick_ls
mpl.rcParams['ytick.labelsize'] = tick_ls
mpl.rcParams['axes.labelsize'] = axes_ls


total_energy = 0.2
xRes = 500
yRes = 500
xVec = np.linspace(-1.0, 1.0, xRes+1)
yVec = np.linspace(-1.0, 1.0, yRes+1)
xMesh, yMesh = np.meshgrid(xVec, yVec)


MMesh = np.genfromtxt("../data/linear-3dof/symp-transform-zpz-xdot_pos/lag_des_3dof" 
                      + str(xRes) + "x" + str(yRes) 
                      + "_finalT10_E%.6f"%(total_energy) + ".txt",delimiter="\t")

# MMesh = np.genfromtxt("../data/linear-3dof/symp-transform-ypz_py_pos/lag_des_3dof" 
#                       + str(xRes) + "x" + str(yRes) 
#                       + "_finalT10_E%.6f"%(total_energy) + ".txt",delimiter="\t")

# MMesh = np.genfromtxt("../src/test_M" + str(xRes) + "x" + str(yRes) + 
#                       "_finalT10_E0.100000.txt",delimiter="\t")t

# min_MMesh, max_MMesh = find_max_min_nan_mat(MMesh)

# normi = mpl.colors.Normalize(vmin = 18, vmax = 558)

# Query few sample values
val1_idx = 0.1*xRes
val1 = xMesh[0,int(val1_idx)]

val2_idx = 0.185*xRes
val2 = xMesh[0,int(val2_idx)]

val3_idx = 0.5*xRes 
val3 = xMesh[0,int(val3_idx)]
# print(val1)
# print(val2)
# print(val3)


plt.close('all')
# fig_cf = plt.figure(figsize = (10,10))
fig_cf, axarr = plt.subplots(2, 1, sharex = True, figsize=(10,10))
ax_cf = axarr[1]
ax_graphM = axarr[0]
# ax_cf = fig_cf.gca()
# ax_cf = fig_cf.add_subplot(2,1,1, aspect = 'equal')
# ax_graphM = fig_cf.add_subplot(2,1,2)
cf = ax_cf.contourf(xMesh, yMesh, MMesh[:,:], 200, 
                    cmap = 'viridis')

ax_cf.plot(xMesh[:,int(val1_idx)], yMesh[:,int(val1_idx)],'k', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$z = %.2f$'%val1)

ax_cf.plot(xMesh[:,int(val2_idx)], yMesh[:,int(val2_idx)],'m', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$z = %.2f$'%val2)

ax_cf.plot(xMesh[:,int(val3_idx)], yMesh[:,int(val3_idx)],'b', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$z = %.2f$'%val3)


"""
# Plotting the analytical NHIM as contour and not masking the values which are on the imposed direction of slice 
"""
ax_cf.plot(-np.sqrt((2*total_energy)/OMEGA3), 0, 'Xr', Markersize = 15)

xMesh_nhim, yMesh_nhim = np.meshgrid(np.linspace(-1,1,100), np.linspace(-1,1,100))
umani = OMEGA3*yMesh_nhim**2 - 2.0*total_energy
smani = OMEGA2*(0.5*yMesh_nhim)**2 + OMEGA3*( (-xMesh_nhim + 0.5*yMesh_nhim)**2 + yMesh_nhim**2) - 2*total_energy

umask = np.zeros_like(umani, dtype=np.bool)
smask = np.zeros_like(smani, dtype=np.bool)
for i, x in enumerate(xMesh_nhim[0,:]):
    for j, y in enumerate(yMesh_nhim[:,0]):
#         if -OMEGA3*y == 0:
#             umask[i,j] = True
        if (LAMBDA + 0.5*OMEGA2 + 0.5*OMEGA3)*y - OMEGA3*x > 0:
            smask[j,i] = True

# Don't mask NHIM that is the sice with the correct direction.            
umani = np.ma.array(umani, mask = umask)
smani = np.ma.array(smani, mask = ~smask)

# Unstable and stable manifolds project as the same as NHIM on this 2D surface
# ax_cf.contour(xMesh_nhim, yMesh_nhim, umani, [0], 
#               colors = 'red', alpha = 1.0, linestyles = 'dashed',
#               linewidths = 3)

ax_cf.contour(xMesh_nhim, yMesh_nhim, smani, [0], 
              colors = 'white', alpha = 1.0, linestyles = 'dashed',
              linewidths = 3)


# ax_cf.set_xlabel(r'$p_y$',  fontsize = fs + 10)
# ax_cf.set_ylabel(r'$p_z$',  fontsize = fs + 10)

ax_cf.set_xlabel(r'$z$',  fontsize = axes_ls + 10)
ax_cf.set_ylabel(r'$p_z$',  fontsize = axes_ls + 10)

# ax_cf.set_xlim([-0.2, 0.2])
# ax_cf.set_ylim([-0.2, 0.2])
ax_cf.set_xticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_aspect('equal')

# ax_cf.set_title(r'$q_1 = q_3 = p_3 = 0, p_1 < 0$', fontsize = 25)
# fig_cf.colorbar(cf)
# cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05,
#                        drawedges = False)

plt.tight_layout()
# plt.savefig('lag_desc_3dof_linear_center_coords.pdf')
plt.show()

# fig_graphM = plt.figure(figsize=(8,8))
# ax_graphM = fig_graphM.gca()

ax_graphM.plot(yMesh[:,int(val1_idx)], MMesh[:,int(val1_idx)], 'k', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$z = %.2f$'%val1)

ax_graphM.plot(yMesh[:,int(val1_idx)], MMesh[:,int(val2_idx)], 'm', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$z = %.2f$'%val2)

ax_graphM.plot(yMesh[:,int(val1_idx)], MMesh[:,int(val3_idx)],'b', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$z = %.2f$'%val3)


# ax_graphM.set_xlabel(r'$x$',  fontsize = fs + 10)
ax_graphM.legend(fontsize = axes_ls - 15, loc = 2)
ax_graphM.set_ylabel(r'$M_{0.5}$',  fontsize = axes_ls + 5)
ax_graphM.set_xlim([-1, 1])
ax_graphM.set_aspect(1.0/ax_graphM.get_data_ratio())

# ax_graphM.set_ylim([min_MMesh, 75])
# # ax_graphM.set_title(r'$y = %f$'%y_val1, fontsize = 20)
# ax_graphM.legend(fontsize = 15)
# #fig_cf.colorbar(cf)
# ax_graphM.set_aspect('equal')


# plt.tight_layout()

# plt.savefig('../data/linear-3dof/symp-transform-zpz-xdot_pos/linear_symp_trans_3dof_M' 
#             + str(xRes) + 'x' + str(yRes) + '_E%.0e'%(total_energy) + '_zpz.png', 
#             dpi = 600, bbox_inches = 'tight')

plt.show()
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# ### Coordinate: $(y,z)$

# %%
# %matplotlib

colormap_options = ['RdGy', 'viridis', 'inferno', 'bone']
lw_slice = 2  #linewidth for 1D slice
ls_slice = '-' #linestyle for 1D slice

tick_ls = 25 #10, 20
axes_ls = 35 #15, 35
mpl.rcParams['xtick.labelsize'] = tick_ls
mpl.rcParams['ytick.labelsize'] = tick_ls
mpl.rcParams['axes.labelsize'] = axes_ls


total_energy = 0.2
xRes = 500
yRes = 500
xVec = np.linspace(-1.0, 1.0, xRes+1)
yVec = np.linspace(-1.0, 1.0, yRes+1)
xMesh, yMesh = np.meshgrid(xVec, yVec)


MMesh = np.genfromtxt("../data/linear-3dof/symp-transform-yz-pxdot_pos/lag_des_3dof" 
                      + str(xRes) + "x" + str(yRes) 
                      + "_finalT10_E%.6f"%(total_energy) + ".txt",delimiter="\t")

# MMesh = np.genfromtxt("../data/linear-3dof/symp-transform-ypz_py_pos/lag_des_3dof" 
#                       + str(xRes) + "x" + str(yRes) 
#                       + "_finalT10_E%.6f"%(total_energy) + ".txt",delimiter="\t")

# MMesh = np.genfromtxt("../src/test_M" + str(xRes) + "x" + str(yRes) + 
#                       "_finalT10_E0.100000.txt",delimiter="\t")t

# min_MMesh, max_MMesh = find_max_min_nan_mat(MMesh)

# normi = mpl.colors.Normalize(vmin = 18, vmax = 558)

# Query few sample values
val1_idx = 0.25*xRes
val1 = xMesh[0,int(val1_idx)]

val2_idx = 0.4*xRes
val2 = xMesh[0,int(val2_idx)]

val3_idx = 0.7*xRes 
val3 = xMesh[0,int(val3_idx)]
# print(val1)
# print(val2)
# print(val3)


plt.close('all')
# fig_cf = plt.figure(figsize = (10,10))
fig_cf, axarr = plt.subplots(2, 1, sharex = True, figsize=(10,10))
ax_cf = axarr[1]
ax_graphM = axarr[0]
# ax_cf = fig_cf.gca()
# ax_cf = fig_cf.add_subplot(2,1,1, aspect = 'equal')
# ax_graphM = fig_cf.add_subplot(2,1,2)
cf = ax_cf.contourf(xMesh, yMesh, MMesh[:,:], 200, 
                    cmap = 'viridis')

ax_cf.plot(xMesh[:,int(val1_idx)], yMesh[:,int(val1_idx)],'k', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$y = %.2f$'%val1)

ax_cf.plot(xMesh[:,int(val2_idx)], yMesh[:,int(val2_idx)],'m', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$y = %.2f$'%val2)

ax_cf.plot(xMesh[:,int(val3_idx)], yMesh[:,int(val3_idx)],'b', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$y = %.2f$'%val3)


"""
# Plotting the analytical NHIM as contour and not masking the values which are on the imposed direction of slice 
"""

# ax_cf.plot(-np.sqrt((2*total_energy)/OMEGA2), 0, 'Xr', Markersize = 15)


xMesh_nhim, yMesh_nhim = np.meshgrid(np.linspace(-1,1,100), np.linspace(-1,1,100))
umani = (OMEGA2*(xMesh_nhim**2 + yMesh_nhim**2) - 2*total_energy)
smani = OMEGA2*( (-xMesh_nhim + 0.5*yMesh_nhim)**2 + yMesh_nhim**2 ) + \
        OMEGA3*( 0.25*yMesh_nhim**2 ) - 2*total_energy

umask = np.zeros_like(umani, dtype=np.bool)
smask = np.zeros_like(smani, dtype=np.bool)
# mask[0:-1, 0:30] = True
# mask[0:30,0:-1] = True
for i, x in enumerate(xMesh_nhim[0,:]):
    for j, y in enumerate(yMesh_nhim[:,0]):
        if -OMEGA2*x + LAMBDA*y > 0:
            umask[j,i] = True
        if (LAMBDA + 0.5*OMEGA2 + 0.5*OMEGA3)*y - OMEGA2*x > 0:
            smask[j,i] = True

# Don't mask NHIM that is the sice with the correct direction.            
umani = np.ma.array(umani, mask = ~umask)
smani = np.ma.array(smani, mask = ~smask)

# Unstable and stable manifolds project as the same as NHIM on this 2D surface
# ax_cf.contour(xMesh_nhim, yMesh_nhim, umani, [0], 
#               colors = 'red', alpha = 1.0, linestyles = 'dashed',
#               linewidths = 3)

# ax_cf.contour(xMesh_nhim, yMesh_nhim, smani, [0], 
#               colors = 'white', alpha = 1.0, linestyles = 'dashed',
#               linewidths = 3)


# ax_cf.set_xlabel(r'$p_y$',  fontsize = fs + 10)
# ax_cf.set_ylabel(r'$p_z$',  fontsize = fs + 10)

ax_cf.set_xlabel(r'$y$',  fontsize = axes_ls + 10)
ax_cf.set_ylabel(r'$z$',  fontsize = axes_ls + 10)

# ax_cf.set_xlim([-0.2, 0.2])
# ax_cf.set_ylim([-0.2, 0.2])
ax_cf.set_xticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_aspect('equal')

# ax_cf.set_title(r'$q_1 = q_3 = p_3 = 0, p_1 < 0$', fontsize = 25)
# fig_cf.colorbar(cf)
# cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05,
#                        drawedges = False)

plt.tight_layout()
# plt.savefig('lag_desc_3dof_linear_center_coords.pdf')
plt.show()

# fig_graphM = plt.figure(figsize=(8,8))
# ax_graphM = fig_graphM.gca()

ax_graphM.plot(yMesh[:,int(val1_idx)], MMesh[:,int(val1_idx)], 'k', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$y = %.2f$'%val1)

ax_graphM.plot(yMesh[:,int(val1_idx)], MMesh[:,int(val2_idx)], 'm', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$y = %.2f$'%val2)

ax_graphM.plot(yMesh[:,int(val1_idx)], MMesh[:,int(val3_idx)],'b', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$y = %.2f$'%val3)


# ax_graphM.set_xlabel(r'$x$',  fontsize = fs + 10)
ax_graphM.legend(fontsize = axes_ls - 15, loc = 2)
ax_graphM.set_ylabel(r'$M_{0.5}$',  fontsize = axes_ls + 5)
ax_graphM.set_xlim([-1, 1])
ax_graphM.set_aspect(1.0/ax_graphM.get_data_ratio())

# ax_graphM.set_ylim([min_MMesh, 75])
# # ax_graphM.set_title(r'$y = %f$'%y_val1, fontsize = 20)
# ax_graphM.legend(fontsize = 15)
# #fig_cf.colorbar(cf)
# ax_graphM.set_aspect('equal')


# plt.tight_layout()

# plt.savefig('../data/linear-3dof/symp-transform-yz-pxdot_pos/linear_symp_trans_3dof_M' 
#             + str(xRes) + 'x' + str(yRes) + '_E%.0e'%(total_energy) + '_yz.png', 
#             dpi = 600, bbox_inches = 'tight')

plt.show()

# %% [markdown]
# ### Coordinate: $(x,p_z)$

# %%
# %matplotlib

only_colormap = 'False'
colormap_options = ['RdGy', 'viridis', 'inferno', 'bone']
lw_slice = 2  #linewidth for 1D slice
ls_slice = '-' #linestyle for 1D slice

tick_ls = 25 #10, 20
axes_ls = 35 #15, 35
mpl.rcParams['xtick.labelsize'] = tick_ls
mpl.rcParams['ytick.labelsize'] = tick_ls
mpl.rcParams['axes.labelsize'] = axes_ls

total_energy = 0.2
xRes = 500
yRes = 500
xVec = np.linspace(-1, 1.0, xRes+1)
yVec = np.linspace(-1, 1.0, yRes+1)
xMesh, yMesh = np.meshgrid(xVec, yVec)

OMEGA2 = 1.0
OMEGA3 = 1.0


MMesh = np.genfromtxt("../data/linear-3dof/symp-transform-xpz-ydot_pos/lag_des_3dof" 
                      + str(xRes) + "x" + str(yRes) 
                      + "_finalT10_E%.6f"%(total_energy) + ".txt",delimiter="\t")

# MMesh = np.genfromtxt("../src/lag_des_3dof" + str(xRes) + "x" + str(yRes) 
#                       + "_finalT10_E%.6f"%(total_energy) + ".txt", delimiter="\t")

# MMesh = np.arctan(MMesh)

# min_MMesh, max_MMesh = find_max_min_nan_mat(MMesh)

# normi = mpl.colors.Normalize(vmin = 18, vmax = 558)

# Query few sample values
y_val1_idx = 0.3*yRes # E = 0.2
# y_val1_idx = 0.28*yRes # E = 0.2
# y_val1_idx = 0.19*yRes # E = 0.4
y_val1 = yMesh[int(y_val1_idx),0]
# print(y_val1)

y_val2_idx = 0.5*yRes
y_val2 = yMesh[int(y_val2_idx),0]
# print(y_val2)

y_val3_idx = 0.725*yRes # E = 0.1
# y_val3_idx = 0.72*yRes # E = 0.2
# y_val3_idx = 0.82*yRes # E = 0.4
y_val3 = yMesh[int(y_val3_idx),0]
# print(y_val3)


if only_colormap == 'True':
    plt.close('all')
    fig_cf = plt.figure()
    ax_cf = fig_cf.gca()

    cf = ax_cf.contourf(xMesh, yMesh, MMesh, 
                        400, cmap = 'viridis')
    # cf = ax_cf.contourf(xMesh, yMesh, np.arctan(MMesh[:,:]), 
    #                     400, cmap = 'viridis')


    ax_cf.set_xlabel(r'$p_y$')
    ax_cf.set_ylabel(r'$p_z$') 

    # cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05,
    #                        drawedges = True)
    # cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05, 
    #                        ticks = [min_MMesh, max_MMesh],
    #                        drawedges = True)
    # cbar.ax.set_yticklabels(['Min', 'Max'])
    ax_cf.set_aspect('equal')
    ax_cf.set_xticks([-1.0, -0.5, 0.0, 0.5, 1.0])
    ax_cf.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
    plt.tight_layout()
    # plt.savefig('lag_desc_linear_2dof_finalT10_E0-4_p1p2_q1zero_tau10.png', dpi = 300,
    #             bbox_inches = 'tight')
    plt.show()


# fig_cf = plt.figure(figsize = (10,10))
fig_cf, axarr = plt.subplots(2, 1, sharex = True, figsize=(10,10))
ax_cf = axarr[1]
ax_graphM = axarr[0]
# ax_cf = fig_cf.gca()
# ax_cf = fig_cf.add_subplot(2,1,1, aspect = 'equal')
# ax_graphM = fig_cf.add_subplot(2,1,2)
cf = ax_cf.contourf(xMesh, yMesh, MMesh[:,:], 200, 
                    cmap = colormap_options[1])

ax_cf.plot(xMesh[int(y_val1_idx),:], yMesh[int(y_val1_idx),:],'k', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$p_z = %.2f$'%y_val1)

ax_cf.plot(xMesh[int(y_val2_idx),:], yMesh[int(y_val2_idx),:],'m', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$p_z = %.2f$'%y_val2)

ax_cf.plot(xMesh[int(y_val3_idx),:], yMesh[int(y_val3_idx),:],'b', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$p_z = %.2f$'%y_val3)



"""
# Plotting the analytical NHIM as contour and not masking the values which are on the imposed direction of slice 
"""

# ax_cf.plot(np.sqrt(2*total_energy/(OMEGA2+OMEGA3)), -np.sqrt(2*total_energy/(OMEGA2+OMEGA3)), 
#            'Xr', Markersize = 15)
# ax_cf.plot(-np.sqrt(2*total_energy/(OMEGA2+OMEGA3)), np.sqrt(2*total_energy/(OMEGA2+OMEGA3)), 
#            'Xr', Markersize = 15)

res = 1000
xMesh_nhim, yMesh_nhim = np.meshgrid(np.linspace(-1,1,res), np.linspace(-1,1,res))
umani = (OMEGA2*(xMesh_nhim**2 + (xMesh_nhim - yMesh_nhim)**2) + \
         OMEGA3*(yMesh_nhim**2 + xMesh_nhim**2) - 2*total_energy)

mask = np.zeros_like(umani, dtype=np.bool)
# mask[0:-1, 0:30] = True
# mask[0:30,0:-1] = True
for i, x in enumerate(xMesh_nhim[0,:]):
    for j, y in enumerate(yMesh_nhim[:,0]):
        if OMEGA2*(2*x - y) + OMEGA3*x > 0:
            mask[j,i] = True 

# Don't mask NHIM that is the sice with the correct direction.            
umani = np.ma.array(umani, mask = ~mask)

cs = ax_cf.contour(xMesh_nhim, yMesh_nhim, umani, [0], 
                  colors = 'red', alpha = 1.0, linestyles = 'dashdot',
                  linewidths = 3)
cs = ax_cf.contour(xMesh_nhim, yMesh_nhim, umani, [0], 
                  colors = 'red', alpha = 1.0, linestyles = 'dashed',
                  linewidths = 3)
cs = ax_cf.contour(xMesh_nhim, yMesh_nhim, umani, [0], 
                  colors = 'white', alpha = 1.0, linestyles = 'dashdot',
                  linewidths = 3)

# ax_cf.plot(x,y,'-r')

# px = get_px_linear_symp_3dof(x,y,total_energy)


ax_cf.set_xlabel(r'$x$',  fontsize = axes_ls + 10)
ax_cf.set_ylabel(r'$p_z$',  fontsize = axes_ls + 10)

ax_cf.set_xticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_aspect('equal')

# ax_cf.set_title(r'$q_1 = q_3 = p_3 = 0, p_1 < 0$', fontsize = 25)
# fig_cf.colorbar(cf)
# cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05,
#                        drawedges = False)

plt.tight_layout()
# plt.savefig('lag_desc_3dof_linear_center_coords.pdf')
plt.show()

# fig_graphM = plt.figure(figsize=(8,8))
# ax_graphM = fig_graphM.gca()
ax_graphM.plot(xMesh[int(y_val1_idx),:], MMesh[int(y_val1_idx),:], 'k', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$p_z = %.2f$'%y_val1)

ax_graphM.plot(xMesh[int(y_val2_idx),:], MMesh[int(y_val2_idx),:], 'm', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$p_z = %.2f$'%y_val2)

ax_graphM.plot(xMesh[int(y_val3_idx),:], MMesh[int(y_val3_idx),:], 'b', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$p_z = %.2f$'%y_val3)

# ax_graphM.set_xlabel(r'$x$',  fontsize = fs + 10)
ax_graphM.legend(fontsize = axes_ls - 15, loc = 1)
ax_graphM.set_ylabel(r'$M_{0.5}$',  fontsize = axes_ls + 5)
ax_graphM.set_xlim([-1, 1])
ax_graphM.set_aspect(1.0/ax_graphM.get_data_ratio())

# ax_graphM.set_ylim([min_MMesh, 75])
# # ax_graphM.set_title(r'$y = %f$'%y_val1, fontsize = 20)
# ax_graphM.legend(fontsize = 15)
# #fig_cf.colorbar(cf)
# ax_graphM.set_aspect('equal')

plt.tight_layout()

plt.savefig('../data/linear-3dof/symp-transform-xpz-ydot_pos/linear_symp_trans_3dof_M' 
            + str(xRes) + 'x' + str(yRes) + '_E%.0e'%(total_energy) + '_xpz.png', 
            dpi = 600, bbox_inches = 'tight')

# plt.show()

# %% [markdown]
# ### Coordinate: $(z, p_y)$

# %%
# %matplotlib

only_colormap = 'False'
colormap_options = ['RdGy', 'viridis', 'inferno', 'bone']
lw_slice = 2  #linewidth for 1D slice
ls_slice = '-' #linestyle for 1D slice


tick_ls = 20 #10, 20
axes_ls = 35 #15, 35
mpl.rcParams['xtick.labelsize'] = tick_ls
mpl.rcParams['ytick.labelsize'] = tick_ls
mpl.rcParams['axes.labelsize'] = axes_ls


total_energy = 0.2
xRes = 500
yRes = 500
xVec = np.linspace(-1, 1.0, xRes+1)
yVec = np.linspace(-1, 1.0, yRes+1)
xMesh, yMesh = np.meshgrid(xVec, yVec)

OMEGA2 = 1.0
OMEGA3 = 1.0


MMesh = np.genfromtxt("../data/linear-3dof/symp-transform-zpy-ydot_pos/lag_des_3dof" 
                      + str(xRes) + "x" + str(yRes) 
                      + "_finalT10_E%.6f"%(total_energy) + ".txt",delimiter="\t")

# MMesh = np.genfromtxt("../src/lag_des_3dof" + str(xRes) + "x" + str(yRes) 
#                       + "_finalT10_E%.6f"%(total_energy) + ".txt", delimiter="\t")

# MMesh = np.arctan(MMesh)

# min_MMesh, max_MMesh = find_max_min_nan_mat(MMesh)

# normi = mpl.colors.Normalize(vmin = 18, vmax = 558)

# Query few sample values
y_val1_idx = 0.4*yRes # E = 0.2
# y_val1_idx = 0.28*yRes # E = 0.2
# y_val1_idx = 0.19*yRes # E = 0.4
y_val1 = yMesh[int(y_val1_idx),0]
# print(y_val1)

y_val2_idx = 0.5*yRes
y_val2 = yMesh[int(y_val2_idx),0]
# print(y_val2)

y_val3_idx = 0.6*yRes # E = 0.1
# y_val3_idx = 0.72*yRes # E = 0.2
# y_val3_idx = 0.82*yRes # E = 0.4
y_val3 = yMesh[int(y_val3_idx),0]
# print(y_val3)


if only_colormap == 'True':
    plt.close('all')
    fig_cf = plt.figure()
    ax_cf = fig_cf.gca()

    cf = ax_cf.contourf(xMesh, yMesh, MMesh, 
                        400, cmap = 'viridis')
    # cf = ax_cf.contourf(xMesh, yMesh, np.arctan(MMesh[:,:]), 
    #                     400, cmap = 'viridis')


    ax_cf.set_xlabel(r'$z$')
    ax_cf.set_ylabel(r'$p_y$') 

    # cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05,
    #                        drawedges = True)
    # cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05, 
    #                        ticks = [min_MMesh, max_MMesh],
    #                        drawedges = True)
    # cbar.ax.set_yticklabels(['Min', 'Max'])
    ax_cf.set_aspect('equal')
    ax_cf.set_xticks([-1.0, -0.5, 0.0, 0.5, 1.0])
    ax_cf.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
    plt.tight_layout()
    # plt.savefig('lag_desc_linear_2dof_finalT10_E0-4_p1p2_q1zero_tau10.png', dpi = 300,
    #             bbox_inches = 'tight')
    plt.show()


# fig_cf = plt.figure(figsize = (10,10))
fig_cf, axarr = plt.subplots(2, 1, sharex = True, figsize=(10,10))
ax_cf = axarr[1]
ax_graphM = axarr[0]
# ax_cf = fig_cf.gca()
# ax_cf = fig_cf.add_subplot(2,1,1, aspect = 'equal')
# ax_graphM = fig_cf.add_subplot(2,1,2)
cf = ax_cf.contourf(xMesh, yMesh, MMesh[:,:], 200, 
                    cmap = colormap_options[1])

ax_cf.plot(xMesh[int(y_val1_idx),:], yMesh[int(y_val1_idx),:],'k', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$p_y = %.2f$'%y_val1)

ax_cf.plot(xMesh[int(y_val2_idx),:], yMesh[int(y_val2_idx),:],'m', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$p_y = %.2f$'%y_val2)

ax_cf.plot(xMesh[int(y_val3_idx),:], yMesh[int(y_val3_idx),:],'b', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$p_y = %.2f$'%y_val3)



"""
# Plotting the analytical NHIM as contour and not masking the values which are on the imposed direction of slice 
"""

# ax_cf.plot(np.sqrt(2*total_energy/(OMEGA2+OMEGA3)), -np.sqrt(2*total_energy/(OMEGA2+OMEGA3)), 
#            'Xr', Markersize = 15)
# ax_cf.plot(-np.sqrt(2*total_energy/(OMEGA2+OMEGA3)), np.sqrt(2*total_energy/(OMEGA2+OMEGA3)), 
#            'Xr', Markersize = 15)

res = 1000
xMesh_nhim, yMesh_nhim = np.meshgrid(np.linspace(-1,1,res), np.linspace(-1,1,res))
umani = ((OMEGA2 + OMEGA3)*0.5*yMesh_nhim**2 + OMEGA3*xMesh_nhim**2 - 2*total_energy)

mask = np.zeros_like(umani, dtype=np.bool)
# mask[0:-1, 0:30] = True
# mask[0:30,0:-1] = True
for i, x in enumerate(xMesh_nhim[0,:]):
    for j, y in enumerate(yMesh_nhim[:,0]):
        if OMEGA3*(-x + y) > 0:
            mask[j,i] = True 

# Don't mask NHIM that is the sice with the correct direction.            
umani = np.ma.array(umani, mask = ~mask)

cs = ax_cf.contour(xMesh_nhim, yMesh_nhim, umani, [0], 
                  colors = 'red', alpha = 1.0, linestyles = 'dashdot',
                  linewidths = 3)

# ax_cf.plot(x,y,'-r')

# px = get_px_linear_symp_3dof(x,y,total_energy)


ax_cf.set_xlabel(r'$z$',  fontsize = axes_ls + 10)
ax_cf.set_ylabel(r'$p_y$',  fontsize = axes_ls + 10)

ax_cf.set_xticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_aspect('equal')

# ax_cf.set_title(r'$q_1 = q_3 = p_3 = 0, p_1 < 0$', fontsize = 25)
# fig_cf.colorbar(cf)
# cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05,
#                        drawedges = False)

plt.tight_layout()
# plt.savefig('lag_desc_3dof_linear_center_coords.pdf')
plt.show()

# fig_graphM = plt.figure(figsize=(8,8))
# ax_graphM = fig_graphM.gca()
ax_graphM.plot(xMesh[int(y_val1_idx),:], MMesh[int(y_val1_idx),:], 'k', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$p_y = %.2f$'%y_val1)

ax_graphM.plot(xMesh[int(y_val2_idx),:], MMesh[int(y_val2_idx),:], 'm', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$p_y = %.2f$'%y_val2)

ax_graphM.plot(xMesh[int(y_val3_idx),:], MMesh[int(y_val3_idx),:], 'b', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$p_y = %.2f$'%y_val3)

# ax_graphM.set_xlabel(r'$x$',  fontsize = fs + 10)
ax_graphM.legend(fontsize = axes_ls - 15)
ax_graphM.set_ylabel(r'$M_{0.5}$',  fontsize = axes_ls + 5)
ax_graphM.set_xlim([-1, 1])
ax_graphM.set_aspect(1.0/ax_graphM.get_data_ratio())

# ax_graphM.set_ylim([min_MMesh, 75])
# # ax_graphM.set_title(r'$y = %f$'%y_val1, fontsize = 20)
# ax_graphM.legend(fontsize = 15)
# #fig_cf.colorbar(cf)
# ax_graphM.set_aspect('equal')

plt.tight_layout()

# plt.savefig('../data/linear-3dof/symp-transform-zpy-ydot_pos/linear_symp_trans_3dof_M' 
#             + str(xRes) + 'x' + str(yRes) + '_E%.0e'%(total_energy) + '_zpy.png', 
#             dpi = 600, bbox_inches = 'tight')

# plt.show()

# %% [markdown]
# ### Coordinate: $(x,z)$

# %%
# %matplotlib

only_colormap = 'False'
colormap_options = ['RdGy', 'viridis', 'inferno', 'bone']
lw_slice = 2  #linewidth for 1D slice
ls_slice = '-' #linestyle for 1D slice


tick_ls = 20 #10, 20
axes_ls = 35 #15, 35
mpl.rcParams['xtick.labelsize'] = tick_ls
mpl.rcParams['ytick.labelsize'] = tick_ls
mpl.rcParams['axes.labelsize'] = axes_ls


total_energy = 0.2
xRes = 500
yRes = 500
xVec = np.linspace(-1, 1.0, xRes+1)
yVec = np.linspace(-1, 1.0, yRes+1)
xMesh, yMesh = np.meshgrid(xVec, yVec)

OMEGA2 = 1.0
OMEGA3 = 1.0

data_path = "../data/linear-3dof/symp-transform-xz-pzdot_pos/"

MMesh = np.genfromtxt( data_path + "lag_des_3dof" 
                      + str(xRes) + "x" + str(yRes) 
                      + "_finalT10_E%.6f"%(total_energy) + ".txt",delimiter="\t")

# MMesh = np.genfromtxt("../src/lag_des_3dof" + str(xRes) + "x" + str(yRes) 
#                       + "_finalT10_E%.6f"%(total_energy) + ".txt", delimiter="\t")

# MMesh = np.arctan(MMesh)

# min_MMesh, max_MMesh = find_max_min_nan_mat(MMesh)

# normi = mpl.colors.Normalize(vmin = 18, vmax = 558)

# Query few sample values
y_val1_idx = 0.2*yRes # E = 0.2
# y_val1_idx = 0.28*yRes # E = 0.2
# y_val1_idx = 0.19*yRes # E = 0.4
y_val1 = yMesh[int(y_val1_idx),0]
# print(y_val1)

y_val2_idx = 0.5*yRes
y_val2 = yMesh[int(y_val2_idx),0]
# print(y_val2)

y_val3_idx = 0.7*yRes # E = 0.1
# y_val3_idx = 0.72*yRes # E = 0.2
# y_val3_idx = 0.82*yRes # E = 0.4
y_val3 = yMesh[int(y_val3_idx),0]
# print(y_val3)


if only_colormap == 'True':
    plt.close('all')
    fig_cf = plt.figure()
    ax_cf = fig_cf.gca()

    cf = ax_cf.contourf(xMesh, yMesh, MMesh, 
                        400, cmap = 'viridis')
    # cf = ax_cf.contourf(xMesh, yMesh, np.arctan(MMesh[:,:]), 
    #                     400, cmap = 'viridis')


    ax_cf.set_xlabel(r'$z$')
    ax_cf.set_ylabel(r'$p_y$') 

    # cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05,
    #                        drawedges = True)
    # cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05, 
    #                        ticks = [min_MMesh, max_MMesh],
    #                        drawedges = True)
    # cbar.ax.set_yticklabels(['Min', 'Max'])
    ax_cf.set_aspect('equal')
    ax_cf.set_xticks([-1.0, -0.5, 0.0, 0.5, 1.0])
    ax_cf.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
    plt.tight_layout()
    # plt.savefig('lag_desc_linear_2dof_finalT10_E0-4_p1p2_q1zero_tau10.png', dpi = 300,
    #             bbox_inches = 'tight')
    plt.show()


# fig_cf = plt.figure(figsize = (10,10))
fig_cf, axarr = plt.subplots(2, 1, sharex = True, figsize=(10,10))
ax_cf = axarr[1]
ax_graphM = axarr[0]
# ax_cf = fig_cf.gca()
# ax_cf = fig_cf.add_subplot(2,1,1, aspect = 'equal')
# ax_graphM = fig_cf.add_subplot(2,1,2)
cf = ax_cf.contourf(xMesh, yMesh, MMesh[:,:], 200, 
                    cmap = colormap_options[1])

ax_cf.plot(xMesh[int(y_val1_idx),:], yMesh[int(y_val1_idx),:],'k', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$z = %.2f$'%y_val1)

ax_cf.plot(xMesh[int(y_val2_idx),:], yMesh[int(y_val2_idx),:],'m', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$z = %.2f$'%y_val2)

ax_cf.plot(xMesh[int(y_val3_idx),:], yMesh[int(y_val3_idx),:],'b', 
           linewidth = lw_slice, linestyle = ls_slice, 
           label = r'$z = %.2f$'%y_val3)



"""
# Plotting the analytical NHIM as contour and not masking the values which are on the imposed direction of slice 
"""

res = 1000
xMesh_nhim, yMesh_nhim = np.meshgrid(np.linspace(-1,1,res), np.linspace(-1,1,res))
umani = (2.0*OMEGA2*xMesh_nhim**2 + OMEGA3*( xMesh_nhim - yMesh_nhim)**2 - 2*total_energy)

mask = np.zeros_like(umani, dtype=np.bool)
# mask[0:-1, 0:30] = True
# mask[0:30,0:-1] = True
for i, x in enumerate(xMesh_nhim[0,:]):
    for j, y in enumerate(yMesh_nhim[:,0]):
        if OMEGA3*(x - y) > 0:
            mask[j,i] = True 

# Don't mask NHIM that is the sice with the correct direction.            
umani = np.ma.array(umani, mask = ~mask)

cs = ax_cf.contour(xMesh_nhim, yMesh_nhim, umani, [0], 
                  colors = 'red', alpha = 1.0, linestyles = 'dashdot',
                  linewidths = 3)

cs = ax_cf.contour(xMesh_nhim, yMesh_nhim, umani, [0], 
                  colors = 'red', alpha = 1.0, linestyles = 'dashed',
                  linewidths = 3)

cs = ax_cf.contour(xMesh_nhim, yMesh_nhim, umani, [0], 
                  colors = 'white', alpha = 1.0, linestyles = 'dashed',
                  linewidths = 3)


ax_cf.set_xlabel(r'$x$',  fontsize = axes_ls + 10)
ax_cf.set_ylabel(r'$z$',  fontsize = axes_ls + 10)

ax_cf.set_xticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax_cf.set_aspect('equal')

# ax_cf.set_title(r'$q_1 = q_3 = p_3 = 0, p_1 < 0$', fontsize = 25)
# fig_cf.colorbar(cf)
# cbar = fig_cf.colorbar(cf, shrink = 0.6, pad = 0.05,
#                        drawedges = False)

plt.tight_layout()
# plt.savefig('lag_desc_3dof_linear_center_coords.pdf')
plt.show()

# fig_graphM = plt.figure(figsize=(8,8))
# ax_graphM = fig_graphM.gca()
ax_graphM.plot(xMesh[int(y_val1_idx),:], MMesh[int(y_val1_idx),:], 'k', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$z = %.2f$'%y_val1)

ax_graphM.plot(xMesh[int(y_val2_idx),:], MMesh[int(y_val2_idx),:], 'm', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$z = %.2f$'%y_val2)

ax_graphM.plot(xMesh[int(y_val3_idx),:], MMesh[int(y_val3_idx),:], 'b', 
               linewidth = lw_slice, linestyle = ls_slice,  
               label = r'$z = %.2f$'%y_val3)

# ax_graphM.set_xlabel(r'$x$',  fontsize = fs + 10)
ax_graphM.legend(fontsize = axes_ls - 15, loc = 2)
ax_graphM.set_ylabel(r'$M_{0.5}$',  fontsize = axes_ls + 5)
ax_graphM.set_xlim([-1, 1])
ax_graphM.set_aspect(1.0/ax_graphM.get_data_ratio())

# ax_graphM.set_ylim([min_MMesh, 75])
# # ax_graphM.set_title(r'$y = %f$'%y_val1, fontsize = 20)
# ax_graphM.legend(fontsize = 15)
# #fig_cf.colorbar(cf)
# ax_graphM.set_aspect('equal')

plt.tight_layout()

plt.savefig('../data/linear-3dof/symp-transform-xz-pzdot_pos/linear_symp_trans_3dof_M' 
            + str(xRes) + 'x' + str(yRes) + '_E%.0e'%(total_energy) + '_xz.eps', 
            dpi = 600, bbox_inches = 'tight')

# plt.show()
